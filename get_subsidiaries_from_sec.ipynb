# %%
import urllib2, re, csv, sys
import lxml.etree as etree
from io import StringIO
from bs4 import BeautifulSoup
from datetime import datetime
from collections import defaultdict

pstart = datetime.now()
dest = open('C:/ipy/sec_scraper/2015-05/fact_counts.csv', 'w')
writer = csv.writer(dest)
#error file
error = open('C:/ipy/sec_scraper/2015-05/errors_21.csv', 'w')
error_write = csv.writer(error)

with open('C:/ipy/sec_scraper/2015-05/ciks_21.csv', 'rb') as f:
	reader = csv.reader(f)
	for i, line in enumerate(reader):
		# for each cik, read html page on sec
		testcik = str(line[0])
		print "cik" + " " + testcik
		url = 'http://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=' + testcik + '&type=10-K&dateb=&owner=exclude&count=40'
		u = urllib2.urlopen(url)
		try:
			html = u.read()
			
			if 'No matching CIK' in html:
				print line[0] + ' is an invalid CIK'
				error_result = [line[0], 'invalid CIK']
				error_write.writerow(error_result)
			else:
				split_name = html.split("<span class=\"companyName\">")
				if len(split_name) > 1:
					split_name = split_name[1].split("<")
					split_name = split_name[0].strip()
				else:
					split_name = "name not found"
				print split_name
				# find latest document link button
				split_links = html.split("\" id=\"documentsbutton\"");
				result = 0
				split_xbrl = split_links[s].split("<a href=\"")
				
				#then check to see if we have an href to follow
				if 'Archives' in split_xbrl[len(split_xbrl) - 1]:
					# then follow the link to filings
					url = 'http://www.sec.gov' + split_xbrl[len(split_xbrl) - 1]
					u = urllib2.urlopen(url)
					
					try:
						html = u.read()
						u.close
						instance_split = html.split("EX-21")
						if len(instance_split) >= 2:
							split_page = instance_split[len(instance_split)-2].split(".xml</a>",1);
							split_xbrl = split_page[len(split_page)-2].split("<a href=\"")
							split_xml = split_xbrl[len(split_xbrl)-1].split("\">")
							
							
					finally:
						u.close
		finally:
			pass

dest.close()
pend = datetime.now()
pdiff = pend - pstart
print pdiff

# %%
import urllib2, re, csv, sys
import lxml.etree as etree
from io import StringIO
from bs4 import BeautifulSoup
from datetime import datetime
from collections import defaultdict

cik = '1067983'
url = 'http://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=' + cik + '&type=10-K&dateb=&owner=exclude&count=40'
u = urllib2.urlopen(url)
try:
    html = u.read()

    if 'No matching CIK' in html:
        print line[0] + ' is an invalid CIK'
        error_result = [line[0], 'invalid CIK']
        error_write.writerow(error_result)
    else:
        split_name = html.split("<span class=\"companyName\">")
        if len(split_name) > 1:
            split_name = split_name[1].split("<")
            split_name = split_name[0].strip()
        else:
            split_name = "name not found"
        print split_name
        # find latest document link button
        split_links = html.split("\" id=\"documentsbutton\"");
        result = 0
        split_xbrl = split_links[0].split("<a href=\"")

        #then check to see if we have an href to follow
        if 'Archives' in split_xbrl[len(split_xbrl) - 1]:
            # then follow the link to filings
            url = 'http://www.sec.gov' + split_xbrl[len(split_xbrl) - 1]
            u = urllib2.urlopen(url)

            try:
                html = u.read()
                u.close
                documents_split = html.split("EX-21")
                if len(documents_split) >= 2:
                    split_page = documents_split[len(documents_split)-2].split(".htm</a>");
                    print len(split_page)
                    split_xbrl = split_page[len(split_page)-2].split("<a href=\"")
                    split_xml = split_xbrl[len(split_xbrl)-1].split("\">")
                    
                    url = 'http://www.sec.gov' + split_xml[0]
                    u = urllib2.urlopen(url)
                    html = u.read()
                    soup = BeautifulSoup(html)
                    
                    result = []
                    allrows = soup.findAll('tr')
                    for row in allrows:
                        result.append([])
                        allcols = row.findAll('td')
                        for col in allcols:
                            thestrings = [s.encode('ascii', 'ignore') for s in col.findAll(text=True)]
                            thetext = ''.join(thestrings)
                            if len(thetext) > 0:
                                result[-1].append(thetext)

            finally:
                u.close
finally:
    pass


for i in result:
    if len(i) > 0:
        loop = i.pop(0)
        #loop.replace('\\xa0', ' ')
        #loop = loop.decode("utf-8").replace(u'\xc2\xa0', u' ').encode("utf-8")
        if len(loop) > 4:
            print split_name + loop
# Out:
# BERKSHIRE HATHAWAY INC
# 2
# BERKSHIRE HATHAWAY INC Company Name
# BERKSHIRE HATHAWAY INC Acme Brick Company
# BERKSHIRE HATHAWAY INC Acme Building Brands, Inc.
# BERKSHIRE HATHAWAY INC Albecca Inc.
# BERKSHIRE HATHAWAY INC AltaLink, L.P.
# BERKSHIRE HATHAWAY INC AltaLink Holdings, L.P.
# BERKSHIRE HATHAWAY INC AltaLink Investments, L.P.
# BERKSHIRE HATHAWAY INC Applied Underwriters, Inc.
# BERKSHIRE HATHAWAY INC Ben Bridge Corporation
# BERKSHIRE HATHAWAY INC Ben Bridge Jeweler, Inc.
# BERKSHIRE HATHAWAY INC Benjamin Moore& Co.
# BERKSHIRE HATHAWAY INC Benjamin Moore& Co., Limited
# BERKSHIRE HATHAWAY INC Benson Industries, Inc.
# BERKSHIRE HATHAWAY INC Berkshire Hathaway Assurance Corporation
# BERKSHIRE HATHAWAY INC Berkshire Hathaway Credit Corporation
# BERKSHIRE HATHAWAY INC Berkshire Hathaway Energy Company
# BERKSHIRE HATHAWAY INC Berkshire Hathaway Finance Corporation
# BERKSHIRE HATHAWAY INC Berkshire Hathaway Homestate Insurance Company
# BERKSHIRE HATHAWAY INC Berkshire Hathaway International Insurance Limited
# BERKSHIRE HATHAWAY INC Berkshire Hathaway Life Insurance Company of Nebraska
# BERKSHIRE HATHAWAY INC Berkshire Hathaway Specialty Insurance Company
# BERKSHIRE HATHAWAY INC BH Media Group, Inc.
# BERKSHIRE HATHAWAY INC BHE Canada, LLC
# BERKSHIRE HATHAWAY INC BHE Canada Holdings Corporation
# BERKSHIRE HATHAWAY INC BHE AltaLink Ltd.
# BERKSHIRE HATHAWAY INC BHE U.S. Transmission, LLC
# BERKSHIRE HATHAWAY INC BHE Renewables, LLC
# BERKSHIRE HATHAWAY INC BHSF, Inc.
# BERKSHIRE HATHAWAY INC BH Finance LLC
# BERKSHIRE HATHAWAY INC BH Shoe Holdings, Inc.
# BERKSHIRE HATHAWAY INC BNSF Railway Company
# BERKSHIRE HATHAWAY INC Boat America Corporation
# BERKSHIRE HATHAWAY INC Borsheim Jewelry Company, Inc.
# BERKSHIRE HATHAWAY INC Brooks Sports, Inc.
# BERKSHIRE HATHAWAY INC The Buffalo News, Inc.
# BERKSHIRE HATHAWAY INC Burlington Northern Santa Fe, LLC
# BERKSHIRE HATHAWAY INC Bushwick Metals LLC
# BERKSHIRE HATHAWAY INC Business Wire, Inc.
# BERKSHIRE HATHAWAY INC California Insurance Company
# BERKSHIRE HATHAWAY INC Campbell Hausfeld/Scott Fetzer Company
